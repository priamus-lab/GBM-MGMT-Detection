# %%
import os
import sys
import getpass
from tqdm import tqdm
sys.path.append("../../HD-BET/HD_BET")
password = getpass.getpass()
#!export PATH="/home/salvatorecapuozzo/HD-BET/:$PATH"
# Out:
# ········

# %%
input_folder = "/home/salvatorecapuozzo/RSNA-BTC-Datasets/OpenNeuroDS000221/"
output_folder = "/home/salvatorecapuozzo/RSNA-BTC-Datasets/OpenNeuroDS000221_ss/"
pswd_inserted = False
for folder in tqdm(os.listdir(input_folder+"0/")):
    input_path = input_folder+"0/"+folder
    output_path = output_folder+"0/"+folder
    if not os.path.exists(output_path):
        os.mkdir(output_path)
    #print(input_path)
    #print(output_path)
    if not pswd_inserted:
        pswd_inserted = True
        # !echo $password | sudo -S su
    #!echo $password | sudo -S /home/salvatorecapuozzo/HD-BET/HD_BET/hd-bet -i $input_path -o $output_path
    # !hd-bet -i $input_path -o $output_path
    #else:
    #    !sudo -S hd-bet -i $input_path -o $output_path
# Out:
#   0%|                                                   | 0/231 [00:00<?, ?it/s]
# [sudo] password di salvatorecapuozzo:
# ########################
# If you are using hd-bet, please cite the following paper:
# Isensee F, Schell M, Tursunova I, Brugnara G, Bonekamp D, Neuberger U, Wick A, Schlemmer HP, Heiland S, Wick W,Bendszus M, Maier-Hein KH, Kickingereder P. Automated brain extraction of multi-sequence MRI using artificialneural networks. arXiv preprint arXiv:1901.11341, 2019.
# ########################
#
# File: /home/salvatorecapuozzo/RSNA-BTC-Datasets/OpenNeuroDS000221/0/sub-010167/sub-010167_FLAIR.nii.gz
# preprocessing...
# image shape after preprocessing:  (93, 147, 110)
# prediction (CNN id)...
# 0
# 1
# 2
# 3
# 4
# running postprocessing...
# exporting segmentation...
# File: /home/salvatorecapuozzo/RSNA-BTC-Datasets/OpenNeuroDS000221/0/sub-010167/sub-010167_T1w.nii.gz
# preprocessing...
# image shape after preprocessing:  (171, 160, 117)
# prediction (CNN id)...
# 0
# 1
# ...
